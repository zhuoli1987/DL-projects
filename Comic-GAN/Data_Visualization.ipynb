# %% [markdown]
# # Data Display

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from glob import glob

import os
import utils
import models

# %%
z_size = (1, 1, 100)
image_size = 64
real_size = (image_size, image_size, 3)

image_path = "./output/gen_epoch_11"

# %% [markdown]
# ## Load Pre-trained Model

# %%
#model = models.GAN(real_size, z_size, image_size)
#models.gen(model, z_size)

# %% [markdown]
# ## Display Images

# %%
_ = utils.view_samples(-1, glob(os.path.join(image_path, '*.jpg')), 8, 8, 'RGB', figsize=(10,10))
plt.show()
