# %%
# %matplotlib inline

import animeface as af
import numpy as np

import PIL.Image
import os
import cv2 
import glob

import matplotlib.pyplot as plt
import time

# %%
# Parameters
image_folder_path = os.getcwd() + '/images'
data_folder = 'data'
data_folder_path = os.getcwd() + '/' + data_folder
max_num = 140000

# %%
# Count files
def countFile(file_path):
    n = 0
    for root, dirs, files in os.walk(file_path):
        n += len(files)
    return n

# %%
# Start to process all the images. Following are the steps:
#   1. Detect anime faces
#   2. Crop and resize the detected faces
#   3. Save the new image
#   4. Delete the original image
image_type = [".jpg", ".png"]
image_index = 43662

while(countFile(data_folder_path) <= max_num):
    print("Waiting...")
    time.sleep(120)
    
    print("Start image processing...")
    if(os.path.isdir(image_folder_path)):
        image_list = []
        count = 0

        # Retrive all items from the folder
        for type in image_type:
            image_list.extend(glob.glob(image_folder_path + "/*" + type))

        # Start to process the images
        for image_path in image_list:
            print('Processing image ' + image_path[-10:])

            try:
                # Load the image
                image = PIL.Image.open(image_path)
                # Detect anime faces
                faces = af.detect(image)
                # Make a copy of the orginal image to draw face detections on
                image_cp = np.copy(image)

                for face_model in faces:
                    # Retrieve the bonding box positions
                    fp = face_model.face.pos
                    # Crop the face
                    face_cropped = image_cp[fp.y: fp.y + fp.height, fp.x: fp.x + fp.width]
                    # Resize the image to match 128 x 128 input
                    face_resized = cv2.resize(face_cropped, (128,128), interpolation = cv2.INTER_CUBIC)
                    # Store the resized image
                    if not os.path.exists(data_folder):
                        os.makedirs(data_folder)
                        
                    face_resized = PIL.Image.fromarray(face_resized)
                    face_resized.save(data_folder_path + '/img_' + str(image_index) + image_path[-4:])
                    # Increase the index
                    image_index += 1

                # Delete the original image
                os.remove(image_path)
                image.close()
                face_resized.close()
            except (IOError, OSError, ValueError):  ## if failed, report it back to the user ##
                try:
                    # Delete the original image
                    os.remove(image_path)
                except OSError:
                    pass
                pass
    
    print("End processing...")
# Out:
# Waiting...
# Start image processing...
# Processing image 036520.jpg
# Processing image 041970.jpg
# Processing image 039613.jpg
# Processing image 029400.jpg
# Processing image 032746.jpg
# Processing image 035029.jpg
# Processing image 034337.jpg
# Processing image 033458.jpg
# Processing image 030636.jpg
# Processing image 028079.jpg
# Processing image 039174.jpg
# Processing image 029367.jpg
# Processing image 031528.jpg
# Processing image 032021.jpg
# Processing image 034450.jpg
# Processing image 043800.jpg
# Processing image 035996.jpg
# Processing image 044809.jpg
# Processing image 033459.jpg
# Processing image 034336.jpg
# Processing image 032747.jpg
# Processing image 029401.jpg
# Processing image 041971.jpg
# Processing image 039612.jpg
# Processing image 036521.jpg
# Processing image 030150.jpg
# Processing image 029415.jpg
# Processing image 041965.jpg
# Processing image 036535.jpg
# Processing image 038518.jpg
# Processing image 030144.jpg
# Processing image 034322.jpg
# Processing image 032753.jpg
# Processing image 032035.jpg
# Processing image 034444.jpg
# Processing image 043814.jpg
# Processing image 030622.jpg
# Processing image 039160.jpg
# Processing image 036253.jpg
# Processing image 029373.jpg
# Processing image 035772.jpg
# Processing image 028045.jpg
# Processing image 037165.jpg
# Processing image 038256.jpg
# Processing image 039148.jpg
# Processing image 031514.jpg
# Processing image 031272.jpg
# Processing image 037603.jpg
# Processing image 038530.jpg
# Processing image 041795.jpg
# Processing image 028723.jpg
# Processing image 033465.jpg
# Processing image 035014.jpg
# Processing image 043182.jpg
# Processing image 033471.jpg
# Processing image 042288.jpg
# Processing image 035000.jpg
# Processing image 043196.jpg
# Processing image 031266.jpg
# Processing image 029429.jpg
# Processing image 036509.jpg
# Processing image 041959.jpg
# Processing image 037617.jpg
# Processing image 028737.jpg
# Processing image 041781.jpg
# Processing image 028051.jpg
# Processing image 037171.jpg
# Processing image 038242.jpg
# Processing image 031500.jpg
# Processing image 032009.jpg
# Processing image 043828.jpg
# Processing image 033317.jpg
# Processing image 035955.jpg
# Processing image 042505.jpg
# Processing image 036284.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a05d84ccc7fc> in <module>()
#      28                 image = PIL.Image.open(image_path)
#      29                 # Detect anime faces
# ---> 30                 faces = af.detect(image)
#      31                 # Make a copy of the orginal image to draw face detections on
#      32                 image_cp = np.copy(image)
#
# ~/anaconda/envs/DL-projects/lib/python3.6/site-packages/animeface-1.1.0-py3.6-macosx-10.7-x86_64.egg/animeface/__init__.py in detect(im)
#      96   else:
#      97     raise ValueError('Unsupported color mode: %s' % im.mode)
# ---> 98   results = _nvxs.detect(im.getdata())
#      99   return [Face(result) for result in results]
#
# KeyboardInterrupt:
