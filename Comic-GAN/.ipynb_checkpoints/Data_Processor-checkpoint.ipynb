# %%
# %matplotlib inline

import animeface as af
import numpy as np

import PIL.Image
import os
import cv2 
import glob

import matplotlib.pyplot as plt
import time

# %%
# Parameters
image_folder_path = os.getcwd() + '/images'
data_folder = 'data'
data_folder_path = os.getcwd() + '/' + data_folder
max_num = 140000

# %%
# Count files
def countFile(file_path):
    n = 0
    for root, dirs, files in os.walk(file_path):
        n += len(files)
    return n

# %%
# Start to process all the images. Following are the steps:
#   1. Detect anime faces
#   2. Crop and resize the detected faces
#   3. Save the new image
#   4. Delete the original image
image_type = [".jpg", ".png"]

while(countFile(data_folder_path) <= max_num):
    print("Waiting...")
    time.sleep(120)
    
    print("Start image processing...")
    if(os.path.isdir(image_folder_path)):
        image_list = []
        image_index = 1
        count = 0

        # Retrive all items from the folder
        for type in image_type:
            image_list.extend(glob.glob(image_folder_path + "/*" + type))

        # Start to process the images
        for image_path in image_list:
            print('Processing image ' + image_path[-10:])

            try:
                # Load the image
                image = PIL.Image.open(image_path)
                # Detect anime faces
                faces = af.detect(image)
                # Make a copy of the orginal image to draw face detections on
                image_cp = np.copy(image)

                for face_model in faces:
                    # Retrieve the bonding box positions
                    fp = face_model.face.pos
                    # Crop the face
                    face_cropped = image_cp[fp.y: fp.y + fp.height, fp.x: fp.x + fp.width]
                    # Resize the image to match 128 x 128 input
                    face_resized = cv2.resize(face_cropped, (128,128), interpolation = cv2.INTER_CUBIC)
                    # Store the resized image
                    if not os.path.exists(data_folder):
                        os.makedirs(data_folder)
                        
                    face_resized = PIL.Image.fromarray(face_resized)
                    face_resized.save(data_folder_path + '/img_' + str(image_index) + image_path[-4:])
                    # Increase the index
                    image_index += 1

                # Delete the original image
                os.remove(image_path)
            except (IOError, OSError, ValueError):  ## if failed, report it back to the user ##
                try:
                    # Delete the original image
                    os.remove(image_path)
                except OSError:
                    pass
                pass
    
    print("End processing...")
# Out:
# Waiting...
# Start image processing...
# Processing image 000608.jpg
# Processing image 000594.jpg
# Processing image 000153.jpg
# Processing image 000151.jpg
# Processing image 000583.jpg
# Processing image 000597.jpg
# Processing image 000154.jpg
# Processing image 000168.jpg
# Processing image 000586.jpg
# Processing image 000169.jpg
# Processing image 000155.jpg
# Processing image 000584.jpg
# Processing image 000590.jpg
# Processing image 000156.jpg
# Processing image 000167.jpg
# Processing image 000601.jpg
# Processing image 000589.jpg
# Processing image 000166.jpg
# Processing image 000600.jpg
# Processing image 000602.jpg
# Processing image 000164.jpg
# Processing image 000165.jpg
# Processing image 000159.jpg
# Processing image 000161.jpg
# Processing image 000607.jpg
# Processing image 000160.jpg
# Processing image 000606.jpg
# Processing image 000604.jpg
# Processing image 000162.jpg
# Processing image 000599.jpg
# Processing image 000605.jpg
# Processing image 000152.png
# Processing image 000595.png
# Processing image 000609.png
# Processing image 000582.png
# Processing image 000596.png
# Processing image 000587.png
# Processing image 000593.png
# Processing image 000592.png
# Processing image 000157.png
# Processing image 000585.png
# Processing image 000591.png
# Processing image 000588.png
# Processing image 000158.png
# Processing image 000603.png
# Processing image 000610.png
# Processing image 000598.png
# Processing image 000163.png
# End processing...
# Waiting...
# Start image processing...
# Processing image 000634.jpg
# Processing image 000620.jpg
# Processing image 000191.jpg
# Processing image 000185.jpg
# Processing image 000184.jpg
# Processing image 000190.jpg
# Processing image 000621.jpg
# Processing image 000635.jpg
# Processing image 000179.jpg
# Processing image 000623.jpg
# Processing image 000186.jpg
# Processing image 000192.jpg
# Processing image 000193.jpg
# Processing image 000187.jpg
# Processing image 000636.jpg
# Processing image 000622.jpg
# Processing image 000178.jpg
# Processing image 000632.jpg
# Processing image 000183.jpg
# Processing image 000196.jpg
# Processing image 000633.jpg
# Processing image 000627.jpg
# Processing image 000625.jpg
# Processing image 000619.jpg
# Processing image 000194.jpg
# Processing image 000180.jpg
# Processing image 000181.jpg
# Processing image 000195.jpg
# Processing image 000624.jpg
# Processing image 000630.jpg
# Processing image 000657.jpg
# Processing image 000643.jpg
# Processing image 000642.jpg
# Processing image 000654.jpg
# Processing image 000655.jpg
# Processing image 000641.jpg
# Processing image 000651.jpg
# Processing image 000650.jpg
# Processing image 000652.jpg
# Processing image 000646.jpg
# Processing image 000647.jpg
# Processing image 000653.jpg
# Processing image 000649.jpg
# Processing image 000660.jpg
# Processing image 000648.jpg
# Processing image 000658.jpg
# Processing image 000659.jpg
# Processing image 000615.jpg
# Processing image 000173.jpg
# Processing image 000198.jpg
# Processing image 000614.jpg
# Processing image 000172.jpg
# Processing image 000616.jpg
# Processing image 000171.jpg
# Processing image 000613.jpg
# Processing image 000175.jpg
# Processing image 000612.jpg
# Processing image 000174.jpg
# Processing image 000176.jpg
# Processing image 000638.jpg
# Processing image 000189.jpg
# Processing image 000188.jpg
# Processing image 000177.jpg
# Processing image 000611.jpg
# Processing image 000637.png
# Processing image 000197.png
# Processing image 000626.png
# Processing image 000182.png
# /Users/zhuoli/anaconda/envs/DL-projects/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Processing image 000631.png
# Processing image 000618.png
# Processing image 000656.png
# Processing image 000640.png
# Processing image 000645.png
# Processing image 000644.png
# Processing image 000629.png
# Processing image 000628.png
# Processing image 000170.png
# Processing image 000617.png
# Processing image 000639.png
# End processing...
# Waiting...
# Start image processing...
# Processing image 000209.jpg
# Processing image 000208.jpg
# Processing image 000694.jpg
# Processing image 000680.jpg
# Processing image 000681.jpg
# Processing image 000695.jpg
# Processing image 000668.jpg
# Processing image 000683.jpg
# Processing image 000697.jpg
# Processing image 000709.jpg
# Processing image 000696.jpg
# Processing image 000682.jpg
# Processing image 000669.jpg
# Processing image 000679.jpg
# Processing image 000686.jpg
# Processing image 000692.jpg
# Processing image 000687.jpg
# Processing image 000691.jpg
# Processing image 000684.jpg
# Processing image 000690.jpg
# Processing image 000676.jpg
# Processing image 000662.jpg
# Processing image 000702.jpg
# Processing image 000716.jpg
# Processing image 000717.jpg
# Processing image 000703.jpg
# Processing image 000688.jpg
# Processing image 000663.jpg
# Processing image 000677.jpg
# Processing image 000661.jpg
# Processing image 000675.jpg
# Processing image 000715.jpg
# Processing image 000700.jpg
# Processing image 000714.jpg
# Processing image 000670.jpg
# Processing image 000710.jpg
# Processing image 000704.jpg
# Processing image 000705.jpg
# Processing image 000711.jpg
# Processing image 000671.jpg
# Processing image 000665.jpg
# Processing image 000673.jpg
# Processing image 000698.jpg
# Processing image 000707.jpg
# Processing image 000706.jpg
# Processing image 000699.jpg
# Processing image 000666.jpg
# Processing image 000672.jpg
# Processing image 000205.jpg
# Processing image 000211.jpg
# Processing image 000210.jpg
# Processing image 000204.jpg
# Processing image 000199.jpg
# Processing image 000212.jpg
# Processing image 000206.jpg
# Processing image 000207.jpg
# Processing image 000203.jpg
# Processing image 000202.jpg
# Processing image 000200.jpg
# Processing image 000201.jpg
# Processing image 000708.png
# Processing image 000678.png
# Processing image 000693.png
# Processing image 000685.png
# Processing image 000689.png
# Processing image 000701.png
# Processing image 000674.png
# Processing image 000664.png
# Processing image 000667.png
# Processing image 000713.png
# Processing image 000712.png
# End processing...
# Waiting...
# Start image processing...
# Processing image 000740.jpg
# Processing image 000754.jpg
# Processing image 000755.jpg
# Processing image 000741.jpg
# Processing image 000757.jpg
# Processing image 000743.jpg
# Processing image 000742.jpg
# Processing image 000752.jpg
# Processing image 000746.jpg
# Processing image 000747.jpg
# Processing image 000753.jpg
# Processing image 000745.jpg
# Processing image 000750.jpg
# Processing image 000744.jpg
# Processing image 000723.jpg
# Processing image 000736.jpg
# Processing image 000722.jpg
# Processing image 000734.jpg
# Processing image 000720.jpg
# Processing image 000721.jpg
# Processing image 000735.jpg
# Processing image 000731.jpg
# Processing image 000725.jpg
# Processing image 000718.jpg
# Processing image 000724.jpg
# Processing image 000730.jpg
# Processing image 000726.jpg
# Processing image 000727.jpg
# Processing image 000729.jpg
# Processing image 000738.jpg
# Processing image 000739.jpg
# Processing image 000749.jpg
# Processing image 000761.jpg
# Processing image 000760.jpg
# Processing image 000748.jpg
# Processing image 000762.jpg
# Processing image 000763.jpg
# Processing image 000766.jpg
# Processing image 000764.jpg
# Processing image 000758.jpg
# Processing image 000759.jpg
# Processing image 000765.jpg
# Processing image 000756.png
# Processing image 000751.png
# Processing image 000737.png
# Processing image 000719.png
# Processing image 000732.png
# Processing image 000733.png
# Processing image 000728.png
# End processing...
# Waiting...
